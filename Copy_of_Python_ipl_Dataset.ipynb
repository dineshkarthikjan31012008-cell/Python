# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshkarthikjan31012008-cell/Python/blob/main/Copy_of_Python_ipl_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
a = pd.read_csv("/content/IPL_Player_Stats.csv")

print(a)

a.head()

a.tail()

a.head(50)


a.tail(50)


a.info()


a.describe()


a.shape

a.size


a.sample()


a.sample(5)

a.columns


a.index
# Out:
#               Player IPL_Team  Matches  Runs  Wickets  Strike_Rate  \
# 0        Virat Kohli      RCB      252  8004        4        131.9
# 1       Rohit Sharma       MI      257  6628       15        131.1
# 2           MS Dhoni      CSK      264  5243        0        135.9
# 3        Chris Gayle     KXIP      142  4965       18        148.9
# 4     AB de Villiers      RCB      184  5162      157        151.7
# 5       David Warner      SRH      184  6563        8        139.9
# 6      Andre Russell      KKR      126  2262       96        174.0
# 7     Kieron Pollard       MI      189  3412       63        147.3
# 8       Suresh Raina      CSK      205  5528       25        136.7
# 9       Shubman Gill       GT      103  3216        0        138.0
# 10      Sanju Samson       RR      170  4419        0        140.0
# 11       Jos Buttler       RR      107  3580        0        147.5
# 12          KL Rahul      LSG      132  4683        0        134.5
# ...

# %%
#Line plot
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")
sns.lineplot(x="Player", y="Runs", data=a ,color='red',label = 'Runs')

plt.title("Player vs Runs ")
plt.legend(loc = "upper right")

plt.show()

# %%
#Scatter plot


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")
sns.scatterplot(x="Matches", y="Wickets", data=a ,color='blue',label = 'Wickets')

plt.title("Wickets taken")
plt.legend(loc = "upper left")

plt.show()

# %%
#Bar plot--1


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")
sns.barplot(x="Player", y="Strike_Rate", data=a ,color='red',label = 'Strike rate ')

plt.title("Strike rate ")

plt.legend(loc = "upper right")

plt.show()

# %%
#Histogram

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")
sns.histplot(x="Runs",  data=a ,color='blue')

plt.title("Runs Histogram")


plt.legend(loc = "upper left")

plt.show()
# Out:
# /tmp/ipykernel_1276/1430220027.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc = "upper left")

# %%
#Count plot

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")
sns.countplot(x="Role", data=a ,color='red',label = 'Role')

plt.title("Roles of palyers")

plt.legend(loc = "upper right")

plt.show()

# %%
#Heat Map--1


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")

c = a.corr(numeric_only=True)
sns.heatmap(c,annot=True , cmap ="inferno" )
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1276/3280975686.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Heat map -- 2


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

a = pd.read_csv("/content/IPL_Player_Stats.csv")

c = a.corr(numeric_only=True)
sns.heatmap(c,annot=False , cmap ="inferno" )
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1276/1240064983.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import os
os.listdir('/content')
# Out:
# ['.config', 'IPL_Player_Stats.csv', 'sample_data']
